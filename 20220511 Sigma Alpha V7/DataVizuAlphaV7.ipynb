# %% [markdown]
# ----------
#
# <h1 align="center"> Static measurements of forces on a NACA0015 hydrofoil in a cavitaiton vein </h1>
# <br>
# <center align="left"> <font size='4'>  Computed by: </font><font size='4' color='#33AAFBD'>Ronald NGOUNOU ZINKOUE </font></center>
# Submitted on 13/06/2022
#
# <br>
#
# ----------

# %% [markdown]
# # Librairies

# %%
import pandas as pd
import numpy as np
import math 
from matplotlib import pyplot  
import matplotlib.pyplot as plt

# %matplotlib inline


import plotly
import plotly.offline as py
import plotly.graph_objs as go
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__) # requires version >= 1.9.0

import cufflinks as cf

from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

cf.go_offline()

import xlsxwriter

from mpl_toolkits import mplot3d

np.seterr(divide='ignore', invalid='ignore')
# Out:
# 5.8.0
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\Admin\OneDrive - HESSO\TFE NGOUNOU\8. Codes\Codes\20220511 Sigma Alpha V7\DataVizuAlphaV7.ipynb Cell 3' in <cell line: 24>()
# ...

# %% [markdown]
# # Importing files

# %% [markdown]
# $\alpha_1$ = 2.5°
#
# Importing the first dataframe: $\alpha_1$ = 2.5
#
# The resulted dataframe is df1

# %%
dataAcquisition_Alpha1 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220503_Alpha1_2p5Cup6p14PressureVary_DataAcqui.txt")

dataBanc_Alpha1 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220505 Last measures\20220505 Data Banc\20220503 DataBanc Alpha Constant\20220503Apha1_2p5Cup6p14PressureVary_DataBanc.xls")

dataAcquisition_Alpha1_selection = dataAcquisition_Alpha1.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha1_selection = dataBanc_Alpha1.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha1_selection.iloc[::-1]

db1_A1 = dataBanc_reversed.reset_index()

df1 = pd.concat([db1_A1, dataAcquisition_Alpha1_selection], axis = 1)
df1.columns = df1.columns.str.replace('[\n]',' ')
#df1.drop([0], inplace = True)  #delete row with alpha=0
df1.sort_values(by='sigma [-]', ascending = False, inplace=True)

#df1[['sigma [-]','M1 [bar rel] ']]

#df1.sort_values(by = 'Alpha [deg]', inplace=True)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\949735041.py:13: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %% [markdown]
# $\alpha_2$ = 7.5°
#
# Importing the first dataframe: $\alpha_2$ = 7.5
#
# The resulted dataframe is df2

# %%
dataAcquisition_Alpha2 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220503_Alpha2_7p5Cup6p14PressureVary_DataAcqui.txt")

dataBanc_Alpha2 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Banc\20220503Apha2_7p5Cup6p14PressureVary_DataBanc.xls")

dataAcquisition_Alpha2_selection = dataAcquisition_Alpha2.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha2_selection = dataBanc_Alpha2.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha2_selection.iloc[::-1]

db1_A2 = dataBanc_reversed.reset_index()

df2 = pd.concat([db1_A2, dataAcquisition_Alpha2_selection], axis = 1)
df2.columns = df2.columns.str.replace('[\n]',' ')
#df2.drop([0], inplace = True)  #delete row with alpha=0
df2.sort_values(by='sigma [-]', ascending = False, inplace=True)

#df2.sort_values(by = 'Alpha [deg]', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\Users\Admin\OneDrive - HESSO\TFE NGOUNOU\8. Codes\Codes\20220511 Sigma Alpha V7\DataVizuAlphaV7.ipynb Cell 8' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Admin/OneDrive%20-%20HESSO/TFE%20NGOUNOU/8.%20Codes/Codes/20220511%20Sigma%20Alpha%20V7/DataVizuAlphaV7.ipynb#ch0000007?line=0'>1</a> dataAcquisition_Alpha2 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220503_Alpha2_7p5Cup6p14PressureVary_DataAcqui.txt")
# ...

# %% [markdown]
# $\alpha_3$ = -7.5°
#
# Importing the first dataframe: alpha3 = -7.5
#
# The resulted dataframe is df3

# %%
dataAcquisition_Alpha3 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220504_Alpha3_-7p5Cup6p14PressureVary_DataAcqui.txt")

dataBanc_Alpha3 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Banc\20220504Apha3_-7p5Cup6p14PressureVary_DataBanc.xls")

dataAcquisition_Alpha3_selection = dataAcquisition_Alpha3.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha3_selection = dataBanc_Alpha3.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha3_selection.iloc[::-1]

db1_A3 = dataBanc_reversed.reset_index()

df3 = pd.concat([db1_A3, dataAcquisition_Alpha3_selection], axis = 1)
df3.columns = df3.columns.str.replace('[\n]',' ')
#df3.drop([0], inplace = True)  #delete row with alpha=0
df3.sort_values(by='sigma [-]', ascending = False, inplace=True)

#df3.sort_values(by = 'Alpha [deg]', inplace=True)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1779305329.py:13: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %% [markdown]
# $\alpha_4$ = 18.5°

# %%
dataAcquisition_Alpha4 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220504_Alpha4_18p5Cup6p14PressureVary_DataAcqui.txt")

dataBanc_Alpha4 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Banc\20220504Apha4_18p5Cup6p14PressureVary_DataBanc.xls")

dataAcquisition_Alpha4_selection = dataAcquisition_Alpha4.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha4_selection = dataBanc_Alpha4.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha4_selection.iloc[::-1]

db1_A4 = dataBanc_reversed.reset_index()

df4 = pd.concat([db1_A4, dataAcquisition_Alpha4_selection], axis = 1)
df4.columns = df4.columns.str.replace('[\n]',' ')
#df4.drop([0], inplace = True)  #delete row with alpha=0
df4.sort_values(by='sigma [-]', ascending = False, inplace=True)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\100288988.py:13: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %% [markdown]
# $\alpha_5$ = 22.5°

# %%
dataAcquisition_Alpha5 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220504_Apha5_22p5_SigmaVary.txt")

dataBanc_Alpha5 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Banc\20220504_Apha5_22p5_SigmaVary.xls")

dataAcquisition_Alpha5_selection = dataAcquisition_Alpha5.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha5_selection = dataBanc_Alpha5.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha5_selection.iloc[::-1]

db1_A5 = dataBanc_reversed.reset_index()

df5 = pd.concat([db1_A5, dataAcquisition_Alpha5_selection], axis = 1)
df5.columns = df5.columns.str.replace('[\n]',' ')
#df5.drop([0], inplace = True)  #delete row with alpha=0
df5.sort_values(by='sigma [-]', ascending = False, inplace=True)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\3390984675.py:13: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %% [markdown]
# $\alpha_6$ = 25°

# %%
dataAcquisition_Alpha6 = pd.read_table(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Acqui\20220510_Alpha6_25deg_SigmaVary.txt")

dataBanc_Alpha6 = pd.read_excel(r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Data  Files\20220511 Mesures Finales\Alpha Constant\Data Banc\20220510_Alpha6_25deg_SigmaVary.xls")

dataAcquisition_Alpha6_selection = dataAcquisition_Alpha6.iloc[:,[1,19,20,21,25,26]]

dataBanc_Alpha6_selection = dataBanc_Alpha6.iloc[:,[1,13,23,75]]
dataBanc_reversed = dataBanc_Alpha6_selection.iloc[::-1]

db1_A6 = dataBanc_reversed.reset_index()

df6 = pd.concat([db1_A6, dataAcquisition_Alpha6_selection], axis = 1)
df6.columns = df6.columns.str.replace('[\n]',' ')
#df6.drop([0], inplace = True)  #delete row with alpha=0
df6.sort_values(by='sigma [-]', ascending = False, inplace=True)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\2213924488.py:13: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
DataSigmaAlpha5 = df5[['sigma [-]', 'Alpha [deg]', 'Cup [m/s]','M1 [bar rel] ']].sort_index()

DataSigmaAlpha5.to_excel(r'C:\Users\uadmin\Desktop\DataAlpha25.xls', sheet_name='Alpha25deg')
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\162699309.py:3: FutureWarning:
#
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.

# %% [markdown]
# Exporting files

# %%
DataSigmaAlpha1 = df1[['sigma [-]', 'Alpha [deg]']]
DataSigmaAlpha2 = df2[['sigma [-]', 'Alpha [deg]']]
DataSigmaAlpha3 = df3[['sigma [-]', 'Alpha [deg]']]
DataSigmaAlpha4 = df4[['Alpha [deg]', 'sigma [-]', 'M1 [bar rel] ']].sort_values(by = "sigma [-]", ascending = False)
DataSigmaAlpha5 = df5[['sigma [-]', 'Alpha [deg]', 'Cup [m/s]','M1 [bar rel] ']]
#DataSigmaAlpha1.to_excel(r'C:\Users\uadmin\Desktop\DataSigmaAlpha1.xls', sheet_name='alpha1')
#DataSigmaAlpha2.to_excel(r'C:\Users\uadmin\Desktop\DataSigmaAlpha2.xls', sheet_name='alpha2')
#DataSigmaAlpha3.to_excel(r'C:\Users\uadmin\Desktop\DataSigmaAlpha3.xls', sheet_name='alpha3')
#DataSigmaAlpha4.to_excel(r'C:\Users\uadmin\Desktop\DataSigmaAlpha4.xls', sheet_name='alpha4')
DataSigmaAlpha5.to_excel(r'C:\Users\uadmin\Desktop\DataSigmaAlpha5.xls', sheet_name='alpha5')


path = r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\8. Codes\Codes\20220507 Sigma Alpha V5\Output_Alpha.xls"

path_visu = r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\6. Preparations\20220509 Plan Exp Visualisation\Output_Alpha4.xls"

#writer = pd.ExcelWriter(path, engine='xlsxwriter')

writer_visu = pd.ExcelWriter(path_visu, engine='xlsxwriter')

#DataSigmaAlpha1.to_excel(writer, sheet_name='alpha1')
#DataSigmaAlpha2.to_excel(writer, sheet_name='alpha2')
#DataSigmaAlpha3.to_excel(writer, sheet_name='alpha3')
#DataSigmaAlpha4.to_excel(writer, sheet_name='alpha4')
#DataSigmaAlpha5.to_excel(writer, sheet_name='alpha5')

DataSigmaAlpha4.to_excel(writer_visu, sheet_name='alpha4_18p5_visu')

#writer.save()
#writer.close()
writer_visu.save()
writer_visu.close()


DataSigmaAlpha5
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\418416900.py:10: FutureWarning:
#
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead. You can set the option io.excel.xls.writer to 'xlwt' to silence this warning. While this option is deprecated and will also raise a warning, it can be globally set and the warning suppressed.
#
# c:\Users\uadmin\AppData\Local\Programs\Python\Python38\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning:
#
# Calling close() on already closed file.
#     sigma [-]  Alpha [deg]  Cup [m/s]  M1 [bar rel]
# 0   23.076414         22.5   6.150702       3.091101
# 17  22.848909         22.5   6.145789       3.052432
# 16  18.649908         22.5   6.148633       2.318225
# 1   18.073967         22.5   6.151715       2.225949
# ...

# %%
# Nb points de mesure:
df1.shape + df2.shape + df3.shape + df4.shape + df5.shape  
total = 27+26+25+22+20
total
# Out:
# 120

# %% [markdown]
# # Correction $\sigma$

# %% [markdown]
# As sigma depends on the pressure P(v), to be more precise in its calculus, we need to correct this value.
#
# Correction sigma1
#
# $P_{up}$ know by experimentation = 0.22 bar

# %% [markdown]
# Equation $Pv(T)$
#
# $log P = A - \frac{B}{T + C}$
#
# p in mm Hg has to be convert in Pa by this operation: /750 * 101325
#
# https://onlinelibrary.wiley.com/doi/pdf/10.1002/9781118135341.app1

# %%
A = 7.94917
B = 1657.462
C = 227.02
rho = 998.3 # [kg/m^3]
Pup = 0.22* 100000  + 101325 # [bar] to [Pa]


df1['Pv(T) [Pa]'] = ( 10 ** (A - B/(df1['Tw [°C]'] + C)) )/750 * 101325

df1['sigma_corr [-]'] = -1 * (df1['Pv(T) [Pa]'] - (df1['M1 [bar rel] ']*100000 + 101325) ) / (0.5*rho*(df1['Cup [m/s]'])**2)   
#utilisé la pression M1, et -1 * car sigma étaient négatifs

# %% [markdown]
# # Defining Parameters

# %%
rho = 998.3 # [kg/m^3]
Nu = 1*10^-6 # [m^2/s]
p_vap = 2237 # [Pa]   #Le mieux serait d'encoder P_vap fonction de T dans mes calculs 
p_atm = 101325 #[Pa]
L = 0.06 # [m]
l = 0.0765 # [m]
D_ref = 0.1 # [m]
S_ref = math.pi*D_ref/4 #[m^2]
S_up = L*l #[m^2]

# %% [markdown]
# Adding a new row with $C_D$ and $C_L$ calculated

# %%
df1['Cd [-]'] = (2* df1['Fd [N]'] ) / (rho * (df1['Cup [m/s]'])**2 * S_up)
df1['Cl [-]'] = (2* df1['Fl [N]'] ) / (rho * (df1['Cup [m/s]'])**2 * S_up)


df2['Cd [-]'] = (2* df2['Fd [N]'] ) / (rho * (df2['Cup [m/s]'])**2 * S_up)
df2['Cl [-]'] = (2* df2['Fl [N]'] ) / (rho * (df2['Cup [m/s]'])**2 * S_up)

df3['Cd [-]'] = (2* df3['Fd [N]'] ) / (rho * (df3['Cup [m/s]'])**2 * S_up)
df3['Cl [-]'] = (2* df3['Fl [N]'] ) / (rho * (df3['Cup [m/s]'])**2 * S_up)


df4['Cd [-]'] = (2* df4['Fd [N]'] ) / (rho * (df4['Cup [m/s]'])**2 * S_up)
df4['Cl [-]'] = (2* df4['Fl [N]'] ) / (rho * (df4['Cup [m/s]'])**2 * S_up)


df5['Cd [-]'] = (2* df5['Fd [N]'] ) / (rho * (df5['Cup [m/s]'])**2 * S_up)
df5['Cl [-]'] = (2* df5['Fl [N]'] ) / (rho * (df5['Cup [m/s]'])**2 * S_up)


df6['Cd [-]'] = (2* df6['Fd [N]'] ) / (rho * (df6['Cup [m/s]'])**2 * S_up)
df6['Cl [-]'] = (2* df6['Fl [N]'] ) / (rho * (df6['Cup [m/s]'])**2 * S_up)

# %% [markdown]
# # Data vizualization

# %% [markdown]
# The aim is to plot:
# 1.   Two 3D graphs representing:
#
#   a) (alpha, sigma, $C_L$)
#
#   b) (alpha, sigma, $C_D$)
#
# 2. A 2D subplot with six figures representing:
#
#   a) ($C_L$, sigma)
#
#       for alpha1, alpha2, alpha3,  alpha4,  alpha5
#
#   b) ($C_D$, sigma)
#
#       for alpha1, alpha2, alpha3,  alpha4,  alpha5

# %% [markdown]
# Observations: Sans cavitation je ne peux pas avoir $C_D$ ou $C_L$ qui vaut 0
# Pour le $C_D$ qui vaut -0.02 il faut voir le calcul d'erreur sur la plage de mesure que je fais.
#
# Lorsque le nombre de cavitation augmente, le coefficient de trainée doit augmenter parce que la trainée est un phénomène qui est négatif.
#
# A l'origine, $P_M$ doit être inférieur à la pression de vaporisation $P_v$ pour qu'il y ait apparition de la cavitation.  A un moment, $P_v$ va devenir supérieur à $P_M$ et on verra apparaitre une chute du coefficient $C_L$

# %%
fig, axs = plt.subplots(6, 2, figsize =(10, 16) , sharex = True, sharey=True)

axs[0, 0].plot(df1['sigma [-]'], df1['Cd [-]'], linestyle =':')
axs[0, 0].scatter(df1['sigma [-]'], df1['Cd [-]'])
axs[0, 0].set_title(r"$\alpha_1 = 2.5$ ")
axs[0, 0].set_xlabel(r"$\sigma$")
axs[0, 0].set_ylabel(r"$C_D$")


axs[1, 0].plot(df2['sigma [-]'], df2['Cd [-]'], linestyle ='-.', c = 'k')
axs[1, 0].scatter(df2['sigma [-]'], df2['Cd [-]'], marker ='*', c = 'k')
axs[1, 0].set_title(r"$\alpha_2 = 7.5$ ")
axs[1, 0].set_xlabel(r"$\sigma$")
axs[1, 0].set_ylabel(r"$C_D$")

axs[2, 0].plot(df3['sigma [-]'], df3['Cd [-]'])
axs[2, 0].scatter(df3['sigma [-]'], df3['Cd [-]'], marker ='x', c = 'g')
axs[2, 0].set_title(r"$\alpha_3 = -7.5$ ")
axs[2, 0].set_xlabel(r"$\sigma$")
axs[2, 0].set_ylabel(r"$C_D$")


axs[3, 0].plot(df4['sigma [-]'], df4['Cd [-]'])
axs[3, 0].scatter(df4['sigma [-]'], df4['Cd [-]'], marker ='+', c = 'r')
axs[3, 0].set_title(r"$\alpha_4 = 18.5$ ")
axs[3, 0].set_xlabel(r"$\sigma$")
axs[3, 0].set_ylabel(r"$C_D$")

axs[4, 0].plot(df5['sigma [-]'], df5['Cd [-]'])
axs[4, 0].scatter(df5['sigma [-]'], df5['Cd [-]'], marker ='o', c = 'y')
axs[4, 0].set_title(r"$\alpha_5 = 22.5$ ")
axs[4, 0].set_xlabel(r"$\sigma$")
axs[4, 0].set_ylabel(r"$C_D$")

axs[5, 0].plot(df6['sigma [-]'], df6['Cd [-]'])
axs[5, 0].scatter(df6['sigma [-]'], df6['Cd [-]'], marker ='s', c = 'm')
axs[5, 0].set_title(r"$\alpha_6 = 25$ ")
axs[5, 0].set_xlabel(r"$\sigma$")
axs[5, 0].set_ylabel(r"$C_D$")

axs[0, 1].plot(df1['sigma [-]'], df1['Cl [-]'], linestyle =':')
axs[0, 1].scatter(df1['sigma [-]'], df1['Cl [-]'])
axs[0, 1].set_title(r"$\alpha_1 = 2.5$ ")
axs[0, 1].set_xlabel(r"$\sigma$")
axs[0, 1].set_ylabel(r"$C_L$")

axs[1, 1].plot(df2['sigma [-]'], df2['Cl [-]'], linestyle ='-.', c = 'k')
axs[1, 1].scatter(df2['sigma [-]'], df2['Cl [-]'], marker ='x', c = 'k')
axs[1, 1].set_title(r"$\alpha_2 = 7.5$ ")
axs[1, 1].set_xlabel(r"$\sigma$")
axs[1, 1].set_ylabel(r"$C_L$")

axs[2, 1].plot(df3['sigma [-]'], df3['Cl [-]'])
axs[2, 1].scatter(df3['sigma [-]'], df3['Cl [-]'], marker ='x', c = 'g')
axs[2, 1].set_title(r"$\alpha_3 = -7.5$ ")
axs[2, 1].set_xlabel(r"$\sigma$")
axs[2, 1].set_ylabel(r"$C_L$")

axs[3, 1].plot(df4['sigma [-]'], df4['Cl [-]'])
axs[3, 1].scatter(df4['sigma [-]'], df4['Cl [-]'], marker ='+', c = 'r')
axs[3, 1].set_title(r"$\alpha_4 = 18.5$")
axs[3, 1].set_xlabel(r"$\sigma$")
axs[3, 1].set_ylabel(r"$C_L$")

axs[4, 1].plot(df5['sigma [-]'], df5['Cl [-]'])
axs[4, 1].scatter(df5['sigma [-]'], df5['Cl [-]'], marker ='o', c = 'y')
axs[4, 1].set_title(r"$\alpha_5 = 22.5$ ")
axs[4, 1].set_xlabel(r"$\sigma$")
axs[4, 1].set_ylabel(r"$C_L$")

axs[5, 1].plot(df6['sigma [-]'], df6['Cl [-]'])
axs[5, 1].scatter(df6['sigma [-]'], df6['Cl [-]'], marker ='s', c = 'm')
axs[5, 1].set_title(r"$\alpha_6 = 25$ ")
axs[5, 1].set_xlabel(r"$\sigma$")
axs[5, 1].set_ylabel(r"$C_L$")
# Out:
# Text(0, 0.5, '$C_L$')

# %%
axs[2, 1].scatter(df3['sigma [-]'], df3['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[2, 1].plot(df3['sigma [-]'], df3['Cl [-]'], linestyle = 'dashdot', c='g')
axs[2, 1].set_ylabel(r"$C_D$ [-]", fontsize = 15)
axs[2, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[2, 1].set_title(r"$\alpha_3$ = -7.5°", fontsize = 15)
axs[2, 1].tick_params(axis="x", labelsize=13)
axs[2, 1].tick_params(axis="y", labelsize=13)

# %% [markdown]
# # Experimental plan

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (15, 15), facecolor='lavender')

# Add scatterplot
ax.scatter(df1['Alpha [deg]'], df1['sigma [-]'], s=120, alpha=0.7 , marker = "^", label =r'$\alpha_1 = 2.5°$',linewidth = 2)

ax.scatter(df2['Alpha [deg]'], df2['sigma [-]'], s=120, alpha= 0.7 ,  marker = "o", label =r'$\alpha_2 = 7.5°$', linewidth = 2)

ax.scatter(df3['Alpha [deg]'], df3['sigma [-]'], s=120, alpha=0.7 , marker = "s", label =r'$\alpha_3 = -7.5°$', c = "dimgray", linewidth = 2)

ax.scatter(df4['Alpha [deg]'], df4['sigma [-]'], s=120, alpha=0.7 , marker = "x", label =r'$\alpha_4 = 18.5°$', linewidth = 2)

ax.scatter(df5['Alpha [deg]'], df5['sigma [-]'], s=120, alpha=0.7 , marker = "x", label =r'$\alpha_5 = 22.5°$', linewidth = 2)

ax.scatter(df6['Alpha [deg]'], df6['sigma [-]'], s=120, alpha=0.7 , marker = "x", label =r'$\alpha_6 = 25°$', linewidth = 2)


plt.title(r"Plan d'expérience pour $\alpha$ constant",fontsize = 20)
plt.xlabel(r"$\alpha$ [°]",fontsize = 20)
plt.ylabel(r"$\sigma$ [-]",fontsize = 20)
plt.yticks(fontsize = 20)
plt.xticks(fontsize = 20)
plt.grid()
sc=plt.legend(loc = 0, fontsize = 17)
plt.show()

# %%
fig, axs = plt.subplots(3,2,figsize = (15, 20), facecolor='lavender')

axs[0, 0].scatter(df1['sigma [-]'], df1['Cd [-]'], s=60, alpha=0.7, edgecolors='y')
axs[0, 0].plot(df1['sigma [-]'], df1['Cd [-]'], linestyle = 'dashdot', c='g')
axs[0, 0].set_ylabel(r"$C_D$ [-]",  fontsize = 15)
axs[0, 0].set_xlabel(r"$\sigma$ [-]" ,  fontsize = 15)
axs[0, 0].set_title(r"$\alpha_1$ = 2.5°",  fontsize = 15)
axs[0, 0].tick_params(axis="x", labelsize=13)
axs[0, 0].tick_params(axis="y", labelsize=13)

axs[0, 1].scatter(df1['sigma [-]'], df1['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[0, 1].plot(df1['sigma [-]'], df1['Cl [-]'], linestyle = 'dashdot')
axs[0, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[0, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[0, 1].set_title(r"$\alpha_1$ = 2.5°", fontsize = 15)
axs[0, 1].tick_params(axis="x", labelsize=13)
axs[0, 1].tick_params(axis="y", labelsize=13)

axs[1, 0].scatter(df2['sigma [-]'], df2['Cd [-]'], s=60, alpha=0.7, edgecolors="k")
axs[1, 0].plot(df2['sigma [-]'], df2['Cd [-]'], linestyle = 'dashdot', c='g')
axs[1, 0].set_ylabel(r"$C_D$ [-]", fontsize = 15)
axs[1, 0].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[1, 0].set_title(r"$\alpha_2$ = 7.5°", fontsize = 15)
axs[1, 0].tick_params(axis="x", labelsize=13)
axs[1, 0].tick_params(axis="y", labelsize=13)

axs[1, 1].scatter(df2['sigma [-]'], df2['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[1, 1].plot(df2['sigma [-]'], df2['Cl [-]'], linestyle = 'dashdot')
axs[1, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[1, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[1, 1].set_title(r"$\alpha_2$ = 7.5°", fontsize = 15)
axs[1, 1].tick_params(axis="x", labelsize=13)
axs[1, 1].tick_params(axis="y", labelsize=13)
#fig.suptitle(r"Evolution de $T$ en fonction de $\sigma$ ",fontsize = 20)

axs[2, 0].scatter(df3['sigma [-]'], df3['Cd [-]'], s=60, alpha=0.7, edgecolors="k")
axs[2, 0].plot(df3['sigma [-]'], df3['Cd [-]'], linestyle = 'dashdot', c='g')
axs[2, 0].set_ylabel(r"$C_D$ [-]", fontsize = 15)
axs[2, 0].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[2, 0].set_title(r"$\alpha_3$ = -7.5°", fontsize = 15)
axs[2, 0].tick_params(axis="x", labelsize=13)
axs[2, 0].tick_params(axis="y", labelsize=13)


axs[2, 1].scatter(df3['sigma [-]'], df3['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[2, 1].plot(df3['sigma [-]'], df3['Cl [-]'], linestyle = 'dashdot')
axs[2, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[2, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[2, 1].set_title(r"$\alpha_3$ = -7.5°", fontsize = 15)
axs[2, 1].tick_params(axis="x", labelsize=13)
axs[2, 1].tick_params(axis="y", labelsize=13)




fig.tight_layout()

# %%
fig, axs = plt.subplots(3,2,figsize = (15, 20), facecolor='lavender')

axs[0, 0].scatter(df4['sigma [-]'], df4['Cd [-]'], s=60, alpha=0.7, edgecolors='y')
axs[0, 0].plot(df4['sigma [-]'], df4['Cd [-]'], linestyle = 'dashdot', c='g')
axs[0, 0].set_ylabel(r"$C_D$ [-]",  fontsize = 15)
axs[0, 0].set_xlabel(r"$\sigma$ [-]" ,  fontsize = 15)
axs[0, 0].set_title(r"$\alpha_4$ = 18.5°",  fontsize = 15)
axs[0, 0].tick_params(axis="x", labelsize=13)
axs[0, 0].tick_params(axis="y", labelsize=13)

axs[0, 1].scatter(df4['sigma [-]'], df4['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[0, 1].plot(df4['sigma [-]'], df4['Cl [-]'], linestyle = 'dashdot')
axs[0, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[0, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[0, 1].set_title(r"$\alpha_4$ = 18.5°", fontsize = 15)
axs[0, 1].tick_params(axis="x", labelsize=13)
axs[0, 1].tick_params(axis="y", labelsize=13)

axs[1, 0].scatter(df5['sigma [-]'], df5['Cd [-]'], s=60, alpha=0.7, edgecolors="k")
axs[1, 0].plot(df5['sigma [-]'], df5['Cd [-]'], linestyle = 'dashdot', c='g')
axs[1, 0].set_ylabel(r"$C_D$ [-]", fontsize = 15)
axs[1, 0].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[1, 0].set_title(r"$\alpha_5$ = 22.5°", fontsize = 15)
axs[1, 0].tick_params(axis="x", labelsize=13)
axs[1, 0].tick_params(axis="y", labelsize=13)

axs[1, 1].scatter(df5['sigma [-]'], df5['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[1, 1].plot(df5['sigma [-]'], df5['Cl [-]'], linestyle = 'dashdot')
axs[1, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[1, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[1, 1].set_title(r"$\alpha_5$ = 22.5°", fontsize = 15)
axs[1, 1].tick_params(axis="x", labelsize=13)
axs[1, 1].tick_params(axis="y", labelsize=13)
#fig.suptitle(r"Evolution de $T$ en fonction de $\sigma$ ",fontsize = 20)

axs[2, 0].scatter(df6['sigma [-]'], df6['Cd [-]'], s=60, alpha=0.7, edgecolors="k")
axs[2, 0].plot(df6['sigma [-]'], df6['Cd [-]'], linestyle = 'dashdot', c='g')
axs[2, 0].set_ylabel(r"$C_D$ [-]", fontsize = 15)
axs[2, 0].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[2, 0].set_title(r"$\alpha_6$ = 25°", fontsize = 15)
axs[2, 0].tick_params(axis="x", labelsize=13)
axs[2, 0].tick_params(axis="y", labelsize=13)


axs[2, 1].scatter(df6['sigma [-]'], df6['Cl [-]'], s=60, alpha=0.7, edgecolors="k")
axs[2, 1].plot(df6['sigma [-]'], df6['Cl [-]'], linestyle = 'dashdot')
axs[2, 1].set_ylabel(r"$C_L$ [-]", fontsize = 15)
axs[2, 1].set_xlabel(r"$\sigma$ [-]", fontsize = 15)
axs[2, 1].set_title(r"$\alpha_6$ = 25°", fontsize = 15)
axs[2, 1].tick_params(axis="x", labelsize=13)
axs[2, 1].tick_params(axis="y", labelsize=13)




fig.tight_layout()

# %% [markdown]
# # 3D Plots
#
# # $C_L$

# %%
fig = plt.figure(figsize=(12,12), facecolor='white')
ax = fig.add_subplot(111, projection='3d')  #111 means my plot has only one figure 
ax = plt.axes(projection='3d')

_=ax.plot3D(df1['sigma [-]'], df1['Alpha [deg]'] , df1['Cl [-]'] , label = r"$\alpha_1$ = 2.5°", linestyle = '-.',linewidth = 4)
_=ax.scatter3D(df1['sigma [-]'], df1['Alpha [deg]'] ,df1['Cl [-]'], edgecolors ='m', marker = "^", linewidth = 6)


_=ax.plot3D(df2['sigma [-]'], df2['Alpha [deg]'] , df2['Cl [-]'], label =r"$\alpha_2$ = 7.5°" ,linewidth = 4) 
_=ax.scatter3D(df2['sigma [-]'], df2['Alpha [deg]'] , df2['Cl [-]'], edgecolors ='k', marker = "o", linewidth = 6)


_=ax.plot3D(df3['sigma [-]'], df3['Alpha [deg]'] , df3['Cl [-]'], label =r"$\alpha_3$ = -7.5°", linewidth = 4) 
_=ax.scatter3D(df3['sigma [-]'], df3['Alpha [deg]'] , df3['Cl [-]'], edgecolors ='g', marker = "H", linewidth = 6)

_=ax.plot3D(df4['sigma [-]'], df4['Alpha [deg]'] , df4['Cl [-]'], label =r"$\alpha_4$= 18.5°" ,linewidth = 4) 
_=ax.scatter3D(df4['sigma [-]'], df4['Alpha [deg]'] , df4['Cl [-]'], edgecolors ='b', marker = "x", linewidth = 6)

_=ax.plot3D(df5['sigma [-]'], df5['Alpha [deg]'] , df5['Cl [-]'], label =r"$\alpha_5$ = 22.5°" ,linewidth = 4) 
_=ax.scatter3D(df5['sigma [-]'], df5['Alpha [deg]'] , df5['Cl [-]'], edgecolors ='b', marker = "x", linewidth = 6)

_=ax.plot3D(df6['sigma [-]'], df6['Alpha [deg]'] , df6['Cl [-]'], label =r"$\alpha_6$ = 25°" ,linewidth = 4) 
_=ax.scatter3D(df6['sigma [-]'], df6['Alpha [deg]'] , df6['Cl [-]'], edgecolors ='b', marker = "x", linewidth = 6)


#view angle
for ii in range(0,360,1):
    ax.view_init(elev=10., azim=ii)

ax.set_title(r"Evolution de $\sigma$ en fonction de $C_L$, $\alpha$ constant",fontsize = 20)
ax.set_xlabel("$\sigma$ [-]", fontsize = 12)
ax.set_ylabel(r'$\alpha$ [°]', fontsize = 14)
ax.set_zlabel("$C_L$", fontsize = 14)

ax.view_init(20,20)
#legend at the end, for all plots
sc=plt.legend(loc = 0, fontsize = 13)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1289208261.py:17: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1289208261.py:20: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1289208261.py:23: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.

# %% [markdown]
# # $C_D$

# %%
fig = plt.figure(figsize=(12,12), facecolor='white')
ax = fig.add_subplot(111, projection='3d')  #111 means my plot has only one figure 
ax = plt.axes(projection='3d')

_=ax.plot3D(df1['sigma [-]'], df1['Alpha [deg]'] , df1['Cd [-]'] , label = r"$\alpha_1$ = 2.5°", linewidth = 4)
_=ax.scatter3D(df1['sigma [-]'], df1['Alpha [deg]'] ,df1['Cd [-]'], edgecolors ='m', marker = "^", linewidth = 6)


_=ax.plot3D(df2['sigma [-]'], df2['Alpha [deg]'] , df2['Cd [-]'], label =r"$\alpha_2$ = 7.5°" ,linewidth = 4) 
_=ax.scatter3D(df2['sigma [-]'], df2['Alpha [deg]'] , df2['Cd [-]'], edgecolors ='k', marker = "o", linewidth = 6)


_=ax.plot3D(df3['sigma [-]'], df3['Alpha [deg]'] , df3['Cd [-]'], label =r"$\alpha_3$ = -7.5°", linewidth = 4) 
_=ax.scatter3D(df3['sigma [-]'], df3['Alpha [deg]'] , df3['Cd [-]'], edgecolors ='g', marker = "H", linewidth = 6)

_=ax.plot3D(df4['sigma [-]'], df4['Alpha [deg]'] , df4['Cd [-]'], label =r"$\alpha_4$= 18.5°" ,linewidth = 4) 
_=ax.scatter3D(df4['sigma [-]'], df4['Alpha [deg]'] , df4['Cd [-]'], edgecolors ='b', marker = "x", linewidth = 6)

_=ax.plot3D(df5['sigma [-]'], df5['Alpha [deg]'] , df5['Cd [-]'], label =r"$\alpha_5$ = 22.5°" ,linewidth = 4) 
_=ax.scatter3D(df5['sigma [-]'], df5['Alpha [deg]'] , df5['Cd [-]'], edgecolors ='b', marker = "x", linewidth = 6)

_=ax.plot3D(df6['sigma [-]'], df6['Alpha [deg]'] , df6['Cd [-]'], label =r"$\alpha_6$ = 25°" ,linewidth = 4) 
_=ax.scatter3D(df6['sigma [-]'], df6['Alpha [deg]'] , df6['Cd [-]'], edgecolors ='b', marker = "x", linewidth = 6)




#view angle
for ii in range(0,360,1):
    ax.view_init(elev=10., azim=ii)

ax.set_title(r"Evolution de $C_D$ en fonction de $\sigma$, $\alpha$ constant",fontsize = 20)
ax.set_xlabel("$\sigma$ [-]", fontsize = 12)
ax.set_ylabel(r'$\alpha$ [°]', fontsize = 14)
ax.set_zlabel("$C_D$", fontsize = 14)

ax.view_init(20,60)
#legend at the end, for all plots
sc=plt.legend(loc =2, fontsize = 13)
# Out:
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1776259843.py:17: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1776259843.py:20: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#
# C:\Users\uadmin\AppData\Local\Temp\ipykernel_36112\1776259843.py:23: UserWarning:
#
# You passed a edgecolor/edgecolors ('b') for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.

# %% [markdown]
# # 2D Plots

# %% [markdown]
# **# Plot 2D global**

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (12, 12), facecolor='lavender')

# Add scatterplot

plt.plot( df1['sigma [-]'] , df1['Cd [-]'], label = r"$\alpha_1$ = 2.5°", linestyle = '-.', linewidth = 2 )
ax.scatter(df1['sigma [-]'], df1['Cd [-]'], s=60, alpha=0.7, marker = "^", linewidth = 2)

plt.plot( df2['sigma [-]'] , df2['Cd [-]'], label = r"$\alpha_2$ = 7.5°", linestyle = 'dashed', linewidth = 2 )
ax.scatter(df2['sigma [-]'], df2['Cd [-]'], s=60, alpha=0.7, marker = "o", linewidth = 2)

plt.plot( df3['sigma [-]'] , df3['Cd [-]'], label = r"$\alpha_3$ = -7.5°", linestyle = 'dotted', linewidth = 2 )
ax.scatter(df3['sigma [-]'], df3['Cd [-]'], s=60, alpha=0.7, marker = "s", linewidth = 2)

plt.plot( df4['sigma [-]'] , df4['Cd [-]'], label = r"$\alpha_4$ = 18.5°", linestyle = (0, (5, 1)), linewidth = 2 )
ax.scatter(df4['sigma [-]'], df4['Cd [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)

plt.plot( df5['sigma [-]'] , df5['Cd [-]'], label = r"$\alpha_5$ = 22.5°", linestyle = (0, (3, 1, 1, 1)), linewidth = 2 )
ax.scatter(df5['sigma [-]'], df5['Cd [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)

plt.plot( df6['sigma [-]'] , df6['Cd [-]'], label = r"$\alpha_6$ = 25°", linestyle = (0, (5, 5)), linewidth = 2 )
ax.scatter(df6['sigma [-]'], df6['Cd [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)

plt.title(r"Expérimentation pour $C_D$ en fonction de $\sigma$",fontsize = 17)
plt.xlabel(r'$\sigma$ [-]',fontsize = 15)
plt.ylabel(r"$C_D$ [-]",fontsize = 15)

plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
# plt.legend(['First List'], loc='upper left')
sc=plt.legend(loc = 0, fontsize = 15)
plt.show()
# 0 = best location

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (12, 12), facecolor='lavender')

# Add scatterplot

plt.plot( df1['sigma [-]'] , df1['Cl [-]'], label = r"$\alpha_1$ = 2.5°", linestyle = '-.', linewidth = 2 )
ax.scatter(df1['sigma [-]'], df1['Cl [-]'], s=60, alpha=0.7, marker = "^", linewidth = 2)

plt.plot( df2['sigma [-]'] , df2['Cl [-]'], label = r"$\alpha_2$ = 7.5°", linestyle = 'dashed', linewidth = 2 )
ax.scatter(df2['sigma [-]'], df2['Cl [-]'], s=60, alpha=0.7, marker = "o", linewidth = 2)

plt.plot( df3['sigma [-]'] , df3['Cl [-]'], label = r"$\alpha_3$ = -7.5°", linestyle = 'dotted', linewidth = 2 )
ax.scatter(df3['sigma [-]'], df3['Cl [-]'], s=60, alpha=0.7, marker = "s", linewidth = 2)

plt.plot( df4['sigma [-]'] , df4['Cl [-]'], label = r"$\alpha_4$ = 18.5°", linestyle = (0, (5, 1)), linewidth = 2 )
ax.scatter(df4['sigma [-]'], df4['Cl [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)

plt.plot( df5['sigma [-]'] , df5['Cl [-]'], label = r"$\alpha_5$ = 22.5°", linestyle = (0, (5, 5)), linewidth = 2 )
ax.scatter(df5['sigma [-]'], df5['Cl [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)

plt.plot( df6['sigma [-]'] , df6['Cl [-]'], label = r"$\alpha_6$ = 25°", linestyle = (0, (3, 1, 1, 1)), linewidth = 2 )
ax.scatter(df6['sigma [-]'], df6['Cl [-]'], s=60, alpha=0.7, marker = "H", linewidth = 2)



plt.title(r"Expérimentation pour $C_L$ en fonction de $\sigma$",fontsize = 17)
plt.xlabel(r'$\sigma$ [-]',fontsize = 15)
plt.ylabel(r"$C_L$ [-]",fontsize = 15)

plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)

sc=plt.legend(loc = 0, fontsize = 15)

# plt.legend(['First List'], loc='upper left')
plt.show()
# 0 = best location

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (10, 10), facecolor='lavender')
# Add scatterplot

plt.plot( df4['sigma [-]'] , df4['Cd [-]'], linestyle = 'dashdot' , c = 'r')
ax.scatter(df4['sigma [-]'], df4['Cd [-]'], s=30, alpha=1, edgecolors="y")

plt.title(r"$\alpha_4$ = 18.5, Evolution de $C_D$ en fonction de $\sigma$",fontsize = 20)
plt.xlabel(r"$\sigma [-]$",fontsize = 15)
plt.ylabel(r"$C_D [-]$", fontsize = 15)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.show()


fig, ax = plt.subplots(figsize = (10, 10), facecolor='lavender')

plt.plot( df4['sigma [-]'] , df4['Cl [-]'], linestyle = 'dashdot')
ax.scatter(df4['sigma [-]'], df4['Cl [-]'], s=30, alpha=1 , edgecolors="k")

plt.title(r"$\alpha_4$ = 18.5, Expérimentation pour $C_L$ en fonction de $\sigma$",fontsize = 17)
plt.xlabel(r"$\sigma [-]$",fontsize = 15)
plt.ylabel(r"$C_L [-]$",fontsize = 15)
plt.yticks(fontsize = 15)
plt.xticks(fontsize = 15)
plt.show()

# %% [markdown]
# # Analysis of 𝛼=−7.5 and  𝛼=7.5

# %% [markdown]
# Une analyse pour  𝛼=−7.5  𝛼=7.5 montrent que les coefficients de trainée sont presqu’identiques car ...

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (10, 10), facecolor='lavender')
# Add scatterplot

plt.plot( df2['sigma [-]'] , df2['Cd [-]'], label =r"$\alpha_2$ = 7.5", linestyle = 'dashdot')
ax.scatter(df2['sigma [-]'], df2['Cd [-]'], s=30, alpha=0.4, edgecolors="y")
plt.plot( df3['sigma [-]'] , df3['Cd [-]'], label =r"$\alpha_3$ = -7.5", linestyle = 'dotted')
ax.scatter(df3['sigma [-]'], df3['Cd [-]'], s=30, alpha=0.4, edgecolors="y")

plt.title(r"Evolution de $C_D$ en fonction de $\sigma$",fontsize = 16)
plt.xlabel(r"$\sigma [-]$",fontsize = 16)
plt.ylabel(r"$C_D [-]$", fontsize = 16)
sc=plt.legend(loc = 0, fontsize = 17)
plt.show()

fig, ax = plt.subplots(figsize = (10, 10), facecolor='lavender')

plt.plot( df2['sigma [-]'] , df2['Cl [-]'],  label =r"$\alpha_2$ = 7.5" , linestyle = 'dashdot')
ax.scatter(df2['sigma [-]'], df2['Cl [-]'], s=30, alpha=0.4 , edgecolors="k")
plt.plot( df3['sigma [-]'] , df3['Cl [-]'], label =r"$\alpha_3$ = -7.5", linestyle = 'dotted')
ax.scatter(df3['sigma [-]'], df3['Cl [-]'], s=30, alpha=0.4 , edgecolors="k")

plt.title(r"Evolution de $C_L$ en fonction de $\sigma$",fontsize = 16)
plt.xlabel(r"$\sigma [-]$",fontsize = 16)
plt.ylabel(r"$C_L [-]$",fontsize = 16)
sc=plt.legend(loc = 0, fontsize = 17)
plt.show()

# %% [markdown]
# Reverse datas for a alpha = -7.5 to see if it is symetric or not

# %%
df3part1 = df3[['sigma [-]', 'Cl [-]']]

#prendre tous les Cl negatif de df3 et ensuite faire *-1
df3part1['ClNeg_Prim'] = (df3part1['Cl [-]'])*-1

#plot the symetric and the normal

fig, ax = plt.subplots(figsize = (10, 10), facecolor='lavender')

plt.plot( df2['sigma [-]'] , df2['Cl [-]'],  label =r"$\alpha_2$ = 7.5" , linestyle = 'dashdot')
ax.scatter(df2['sigma [-]'], df2['Cl [-]'], s=30, alpha=0.4 , edgecolors="k")

plt.plot( df3part1['sigma [-]'] , df3part1['ClNeg_Prim'], label =r"$\alpha_3'$ = -7.5", linestyle = 'dotted')
ax.scatter(df3part1['sigma [-]'], df3part1['ClNeg_Prim'], s=30, alpha=0.4 , edgecolors="k")

plt.title(r"Evolution de $C_L$ en fonction de $\sigma$",fontsize = 16)
plt.xlabel(r"$\sigma [-]$",fontsize = 16)
plt.ylabel(r"$C_L [-]$",fontsize = 16)
sc=plt.legend(loc = 0, fontsize = 17)
plt.show()

#df3part1[['sigma [-]', 'ClNeg_Prim']]

#df2[['sigma [-]', 'Cl [-]']]

# Les points choisis pour sigma ne sont pas les mêmes à une décimale près.

# %% [markdown]
# # Export to Excel

# %%
DataAlpha1 = df1[['sigma [-]', 'Alpha [deg]']]
DataAlpha2 = df2[['sigma [-]', 'Alpha [deg]']]
DataAlpha3 = df3[['sigma [-]', 'Alpha [deg]']]
DataAlpha4 = df4[['sigma [-]', 'Alpha [deg]']]
DataAlpha5 = df5[['sigma [-]', 'Alpha [deg]']]
DataAlpha6 = df6[['sigma [-]', 'Alpha [deg]']]

path = r"D:\TFE NGOUNOU - Balance Cavitation\HESSO\Balance Cavitation - General\TFE NGOUNOU\6. Preparations\20220509 Plan Exp Visualisation\20220512Output_AlphaCst.xls"

writer = pd.ExcelWriter(path, engine='xlsxwriter')

DataAlpha1.to_excel(writer, sheet_name='Alpha1')
DataAlpha2.to_excel(writer, sheet_name='Alpha2')
DataAlpha3.to_excel(writer, sheet_name='Alpha3')
DataAlpha4.to_excel(writer, sheet_name='Alpha4')
DataAlpha5.to_excel(writer, sheet_name='Alpha5')
DataAlpha6.to_excel(writer, sheet_name='Alpha6')

writer.save()
writer.close()
# Out:
# c:\Users\uadmin\AppData\Local\Programs\Python\Python38\lib\site-packages\xlsxwriter\workbook.py:339: UserWarning:
#
# Calling close() on already closed file.

# %%
df4[['Alpha [deg]', 'sigma [-]', 'M1 [bar rel] ', 'Cd [-]','Cl [-]' ]]
# Out:
#     Alpha [deg]  sigma [-]  M1 [bar rel]     Cd [-]    Cl [-]
# 0          18.5  23.085864       3.097315  0.549548  3.138405
# 26         18.5  21.549264       2.809740  0.541951  3.163651
# 25         18.5  17.854245       2.175657  0.551455  3.171889
# 1          18.5  17.817989       2.199420  0.557013  3.144157
# 2          18.5  15.265456       1.758418  0.556848  3.146685
# 3          18.5  13.250671       1.408576  0.560319  3.157221
# 4          18.5  12.931234       1.350692  0.561929  3.176690
# 24         18.5  12.849534       1.335638  0.556754  3.181986
# 5          18.5  11.948784       1.191363  0.563073  3.167377
# 6          18.5  10.806625       0.986067  0.608986  3.273278
# 7          18.5  10.256517       0.898757  0.640595  3.316848
# 8          18.5  10.023068       0.856542  0.653473  3.325576
# 9          18.5   9.632244       0.782750  0.696788  3.400070
# 10         18.5   9.506457       0.759258  0.844523  3.955226
# ...

# %%
# Initialize layout
fig, ax = plt.subplots(figsize = (15, 15), facecolor='lavender')

# Add scatterplot
plt.plot(df1['Cd [-]'], df1['Cl [-]'], label =r'$\alpha_1 = 2.5°$', linestyle = '-.' ,linewidth = 2)
ax.scatter(df1['Cd [-]'], df1['Cl [-]'], s=60, alpha=0.7 , marker = "^", linewidth = 2)

plt.plot(df2['Cd [-]'], df2['Cl [-]'], label =r'$\alpha_2 = 7.5°$', linestyle = 'dashed', linewidth = 2)
ax.scatter(df2['Cd [-]'], df2['Cl [-]'], s=60, alpha= 0.7 ,  marker = "o", linewidth = 2)

plt.plot(df3['Cd [-]'], df3['Cl [-]'], label =r'$\alpha_3 = -7.5°$', linestyle = 'dotted', c = "dimgray" , linewidth = 2)
ax.scatter(df3['Cd [-]'], df3['Cl [-]'], s=60, alpha=0.7 , marker = "s", c = "dimgray", linewidth = 2)

plt.plot(df4['Cd [-]'], df4['Cl [-]'],  label =r'$\alpha_4 = 18.5°$', linestyle = (0, (5, 1)), linewidth = 2)
ax.scatter(df4['Cd [-]'], df4['Cl [-]'], s=60, alpha=0.7 , marker = "x", linewidth = 2)

plt.plot(df5['Cd [-]'], df5['Cl [-]'],  label =r'$\alpha_5 = 22.5°$', linestyle = (0, (5, 5)), linewidth = 2)
ax.scatter(df5['Cd [-]'], df5['Cl [-]'], s=60, alpha=0.7 , marker = "x", linewidth = 2)

plt.plot(df6['Cd [-]'], df6['Cl [-]'],  label =r'$\alpha_6 = 25°$', linestyle = (0, (5, 3)), linewidth = 2)
ax.scatter(df6['Cd [-]'], df6['Cl [-]'], s=60, alpha=0.7 , marker = "x", linewidth = 2)

plt.title(r"Evolution de $C_D$ en fonction de $C_L$",fontsize = 20)
plt.xlabel(r"$C_D$ [-]",fontsize = 20)
plt.ylabel(r"$C_L$ [-]",fontsize = 20)

sc=plt.legend(loc = 0, fontsize = 17)
plt.show()

# %% [markdown]
# Export tables to Latex

# %%
df6Latex = df6[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df6_Alpha25.tex','w') as tf:
    tf.write(df6Latex.to_latex())

# %%
df1Latex = df1[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df1_Alpha2p5.tex','w') as tf:
    tf.write(df1Latex.to_latex())


df2Latex = df2[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df2_Alpha7p5.tex','w') as tf:
    tf.write(df2Latex.to_latex())


df3Latex = df3[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df3_Alpha_Moins_7p5.tex','w') as tf:
    tf.write(df3Latex.to_latex())


df4Latex = df4[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df4_Alpha18p5.tex','w') as tf:
    tf.write(df4Latex.to_latex())


df5Latex = df5[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df5_Alpha22p5.tex','w') as tf:
    tf.write(df5Latex.to_latex())


df6Latex = df6[['Alpha [deg]', 'sigma [-]', 'Cup [m/s]', 'M1 [bar rel] ', 'Cd [-]', 'Cl [-]', 'Tw [°C]' ]]
with open('df6_Alpha25.tex','w') as tf:
    tf.write(df6Latex.to_latex())
